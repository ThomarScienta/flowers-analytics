# %%
# %pip install -U "git+https://github.com/ThomarScienta/flowers-analytics.git@main#subdirectory=."
dbutils.library.restartPython()

from flowers.silver import to_iris_silver

bronze_table = "dev_flowers.bronze.iris"
silver_table = "dev_flowers.silver.iris"

df_bronze = spark.table(bronze_table)

df_silver = to_iris_silver(df_bronze)

# ---- Write Silver Table (full refresh) ----
(
    df_silver.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(silver_table)
)

print(f"Silver table written: {silver_table}")
